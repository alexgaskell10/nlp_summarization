# %% [markdown]
# ## Run in high RAM runtime or will crash OOM error

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Documents/Imperial/Individual_project/Technical-Writer-Assistant')
# os.chdir('/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-dataset')
! pwd
# Out:
# /content/drive/My Drive/Documents/Imperial/Individual_project/Technical-Writer-Assistant

# %%
! python explore_cnn-dm.py colab
# Out:
# ['/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/cnn_dm/val.target', '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/cnn_dm/train.target', '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/cnn_dm/test.target', '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/cnn_dm/val.source', '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/cnn_dm/train.source', '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/cnn_dm/test.source']
# val.target
# train.target
# test.target
# val.source
# train.source
# tcmalloc: large alloc 1160765440 bytes == 0x1cc7e000 @  0x7f1487fd31e7 0x59203c 0x4ca610 0x56697a 0x5a4be1 0x5a5cda 0x4ce182 0x5667d2 0x5a4be1 0x5a5e9e 0x5bcf28 0x50a2bf 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f1487bd0b97 0x5b250a
# tcmalloc: large alloc 2321522688 bytes == 0xec578000 @  0x7f1487fd31e7 0x54485f 0x52dc9d 0x52ed2f 0x53e34a 0x4f27d0 0x50a2bf 0x50bfb4 0x507d64 0x5090b7 0x594931 0x5a47fc 0x5a5cda 0x4baf4c 0x5bcf53 0x50a2bf 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f1487bd0b97 0x5b250a
# tcmalloc: large alloc 4643045376 bytes == 0x176b72000 @  0x7f1487fd31e7 0x54485f 0x52dc9d 0x52ed2f 0x53e34a 0x4f27d0 0x50a2bf 0x50bfb4 0x507d64 0x5090b7 0x594931 0x5a47fc 0x5a5cda 0x4baf4c 0x5bcf53 0x50a2bf 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f1487bd0b97 0x5b250a
# tcmalloc: large alloc 4625121280 bytes == 0x61f7c000 @  0x7f1487fd31e7 0x5aca9b 0x4bb106 0x5bcf53 0x50a2bf 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f1487bd0b97 0x5b250a
# tcmalloc: large alloc 4625121280 bytes == 0x175a58000 @  0x7f1487fd31e7 0x54485f 0x545c2a 0x4bb205 0x5bcf53 0x50a2bf 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f1487bd0b97 0x5b250a
# test.source
