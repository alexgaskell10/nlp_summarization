# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !python3 /content/drive/My\ Drive/Documents/Imperial/Individual_project/bart_save.py | head -n 7
# !cat /content/drive/My\ Drive/Documents/Imperial/Individual_project/bart_save.py | head -n 7
# !ls /content/drive/My\ Drive/Documents/Imperial/Individual_project/
# Out:
# cuda
# import torch
#
# if torch.cuda.is_available():
#     device = torch.device('cuda')
# else:
#     device = torch.device('cpu')
#
# BART_experiment.ipynb  colabs_test.py  __pycache__
# bart_save.py	       __init__.py     test_save_bert.pt
# colabs_test.ipynb      old	       test_save.pt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import importlib

try:
    importlib.reload(mod)
except NameError:
    mod = importlib.import_module('drive.My Drive.Documents.Imperial.Individual_project.bart_save')
# Out:
# cuda
