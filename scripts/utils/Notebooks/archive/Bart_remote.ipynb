# %%
# !pip install fairseq

# %%
import torch
import fairseq

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !python3 /content/drive/My\ Drive/Documents/Imperial/Individual_project/colabs_test.py
# !ls /content/drive/My\ Drive/Documents/Imperial/Individual_project/
# !ls /content/drive/My\ Drive/Documents/Imperial/Individual_project/pj1000.pkl
# Out:
# python3: can't open file '/content/drive/My Drive/Documents/Imperial/Individual_project/colabs_test.py': [Errno 2] No such file or directory
# bart_save.py  cnn_dm  __init__.py  Notebooks  pj1000.pkl  __pycache__
# '/content/drive/My Drive/Documents/Imperial/Individual_project/pj1000.pkl'

# %%
import importlib

t = importlib.import_module('drive.My Drive.Documents.Imperial.Individual_project.bart_save')
# Out:
# Ready
# Downloading: "https://github.com/pytorch/fairseq/archive/master.zip" to /root/.cache/torch/hub/master.zip
# 100%|██████████| 3715581256/3715581256 [04:32<00:00, 13656571.68B/s]
# loading archive file http://dl.fbaipublicfiles.com/fairseq/models/bart.large.cnn.tar.gz from cache at /root/.cache/torch/pytorch_fairseq/6ee6af21df382be253b815b53834cd71f61b7ebb83deaa2d10c5d3f94db833cb.3a612b08cd8ff157daf01330f2160f0889831fcb543ec25aa63e38c726167380
# extracting archive file /root/.cache/torch/pytorch_fairseq/6ee6af21df382be253b815b53834cd71f61b7ebb83deaa2d10c5d3f94db833cb.3a612b08cd8ff157daf01330f2160f0889831fcb543ec25aa63e38c726167380 to temp dir /tmp/tmp93i16uqw
# | [source] dictionary: 50264 types
# | [target] dictionary: 50264 types
# 1042301B [00:00, 1223512.74B/s]
# 456318B [00:01, 431468.20B/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ...

# %%
_ = importlib.reload(t)
