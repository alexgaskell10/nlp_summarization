# %% [markdown]
#  <!-- ## Run in high RAM runtime or will crash OOM error -->

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Version from https://github.com/armancohan/long-summarization

# %%
import os
os.chdir('/content/drive/My Drive/Documents/Imperial/Individual_project/Covid01/long-summarization')
! pip install -r requirements.txt
! pip install tensorflow-gpu==1.15.2

# %%
# os.chdir('/content/drive/My Drive/Documents/Imperial/Individual_project/long-summarization')
# # ! cat run_summarization.py
# ! cat batch_reader.py

# %%
# Training
os.chdir('/content/drive/My Drive/Documents/Imperial/Individual_project/Covid01/long-summarization')
# ! cat run_summarization.py
! python run_summarization.py \
    --mode=train \
    --data_path='/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed_da/train.bin' \
    --vocab_path='/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed_da/vocab' \
    --log_root=logroot \
    --exp_name=test-experiment \
    --max_dec_steps=210 \
    --max_enc_steps=2500 \
    --num_sections=5 \
    --max_section_len=500 \
    --batch_size=1 \
    --vocab_size=50000 \
    --use_do=True \
    --optimizer=adagrad \
    --do_prob=0.25 \
    --hier=True \
    --split_intro=True \
    --fixed_attn=True \
    --legacy_encoder=False \
    --coverage=False
# Out:
# WARNING:tensorflow:From run_summarization.py:496: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From run_summarization.py:396: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0603 20:33:36.825801 139923158271872 module_wrapper.py:139] From run_summarization.py:396: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From run_summarization.py:396: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0603 20:33:36.826033 139923158271872 module_wrapper.py:139] From run_summarization.py:396: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING:tensorflow:From run_summarization.py:397: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# ...

# %%
# Decode
os.chdir('/content/drive/My Drive/Documents/Imperial/Individual_project/long-summarization')
! python run_summarization.py \
    --mode=decode \
    --single_pass=True \
    --data_path='/content/drive/My Drive/Documents/Imperial/Individual_project/long-summarization/data/test.bin' \
    --vocab_path='/content/drive/My Drive/Documents/Imperial/Individual_project/long-summarization/data/vocab' \
    --log_root=logroot \
    --exp_name=test-experiment \
    --max_dec_steps=210 \
    --max_enc_steps=2500 \
    --num_sections=5 \
    --max_section_len=500 \
    --batch_size=4 \
    --vocab_size=50000 \
    --use_do=True \
    --optimizer=adagrad \
    --do_prob=0.25 \
    --hier=True \
    --split_intro=True \
    --fixed_attn=True \
    --legacy_encoder=False \
    --coverage=False

# %%
os.chdir('/content/drive/My Drive/Documents/Imperial/Individual_project/long-summarization/data')
! ls
# Out:
# small.bin  test.bin  vocab

# %%
with open('/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed_da/train.bin', 'rb') as f:
    for n,l in enumerate(f):
        print(l)
        if n > 100:
            break

# %%
with open('/content/drive/My Drive/Documents/Imperial/Individual_project/long-summarization/data/small.bin', 'rb') as f:
    for n,l in enumerate(f):
        print(l)
        if n > 100:
            break

# %%
## Convert train files to bin

# Join seperate arxiv and pubmed datafiles into single file
# os.chdir('/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/')
# ! cat arxiv/val.txt pubmed/val.txt > arxiv-pubmed/val.txt
# ! cat arxiv/test.txt pubmed/test.txt > arxiv-pubmed/test.txt
# ! cat arxiv/train.txt pubmed/train.txt > arxiv-pubmed/train.txt

# Confirm same number of lines
# ! wc -l arxiv/val.txt 
# ! wc -l pubmed/val.txt 
# ! wc -l arxiv-pubmed/val.txt
# ! wc -l arxiv/train.txt 
# ! wc -l pubmed/train.txt 
# ! wc -l arxiv-pubmed/train.txt
# ! wc -l arxiv/test.txt 
# ! wc -l pubmed/test.txt 
# ! wc -l arxiv-pubmed/test.txt

# os.chdir('/content/drive/My Drive/Documents/Imperial/Individual_project/long-summarization')
# ! python scripts/json_to_bin.py \
#     '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed/val.txt' \
#     '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed_da/val.bin'
# ! python scripts/json_to_bin.py \
#     '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed/test.txt' \
#     '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed_da/test.bin'
# ! python scripts/json_to_bin.py \
#     '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed/train.txt' \
#     '/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed_da/train.bin' \
#     --vocab_file='/content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed_da/vocab'
# Out:
# Finished writing file /content/drive/My Drive/Documents/Imperial/Individual_project/datasets/arxiv-pubmed_da/train.bin
#
# Writing vocab file...
# Finished writing vocab file
